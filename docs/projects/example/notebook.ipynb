# %% [markdown]
# # Notebook
#
# ## Overview
#
# Documentation can also include notebooks. The H1 title will be used to label the notebook in the table of contents, so use H2 for section headers.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,5,51)
y = x**2

plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("quadratic")
plt.show()
